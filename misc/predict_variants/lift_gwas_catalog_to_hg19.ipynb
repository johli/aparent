# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy
import pandas as pd
import os

# %%
gwas_df = pd.read_csv('gwas_catalog_v1.0.2-associations_e96_r2019-11-21.tsv', delimiter='\t')

print(gwas_df.head())
# Out:
#   DATE ADDED TO CATALOG  PUBMEDID FIRST AUTHOR        DATE   JOURNAL  \
# 0            2018-08-29  29912962   Feitosa MF  2018-06-18  PLoS One
# 1            2018-08-29  29912962   Feitosa MF  2018-06-18  PLoS One
# 2            2018-08-29  29912962   Feitosa MF  2018-06-18  PLoS One
# 3            2018-08-29  29912962   Feitosa MF  2018-06-18  PLoS One
# 4            2018-08-29  29912962   Feitosa MF  2018-06-18  PLoS One
#
#                                    LINK  \
# 0  www.ncbi.nlm.nih.gov/pubmed/29912962
# 1  www.ncbi.nlm.nih.gov/pubmed/29912962
# 2  www.ncbi.nlm.nih.gov/pubmed/29912962
# 3  www.ncbi.nlm.nih.gov/pubmed/29912962
# 4  www.ncbi.nlm.nih.gov/pubmed/29912962
#
#                                                STUDY  \
# 0  Novel genetic associations for blood pressure ...
# 1  Novel genetic associations for blood pressure ...
# 2  Novel genetic associations for blood pressure ...
# 3  Novel genetic associations for blood pressure ...
# 4  Novel genetic associations for blood pressure ...
#
#                                        DISEASE/TRAIT  \
# 0  Diastolic blood pressure x alcohol consumption...
# 1  Diastolic blood pressure x alcohol consumption...
# 2  Diastolic blood pressure x alcohol consumption...
# 3  Diastolic blood pressure x alcohol consumption...
# 4  Diastolic blood pressure x alcohol consumption...
#
#                                  INITIAL SAMPLE SIZE  \
# 0  12,758 European ancestry heavy drinkers, 1,326...
# 1  12,758 European ancestry heavy drinkers, 1,326...
# 2  12,758 European ancestry heavy drinkers, 1,326...
# 3  12,758 European ancestry heavy drinkers, 1,326...
# 4  12,758 European ancestry heavy drinkers, 1,326...
#
#                              REPLICATION SAMPLE SIZE  ... PVALUE_MLOG  \
# 0  42,079 European ancestry heavy drinkers, 217 A...  ...   18.698970
# 1  42,079 European ancestry heavy drinkers, 217 A...  ...   18.096910
# 2  42,079 European ancestry heavy drinkers, 217 A...  ...   12.522879
# 3  42,079 European ancestry heavy drinkers, 217 A...  ...   17.301030
# 4  42,079 European ancestry heavy drinkers, 217 A...  ...    8.522879
#
#   P-VALUE (TEXT) OR or BETA 95% CI (TEXT)  \
# 0           (EA)        NaN           NaN
# 1           (EA)        NaN           NaN
# 2           (EA)        NaN           NaN
# 3           (EA)        NaN           NaN
# 4           (EA)        NaN           NaN
#
#                         PLATFORM [SNPS PASSING QC] CNV  \
# 0  Affymetrix, Illumina [up to 39321347] (imputed)   N
# 1  Affymetrix, Illumina [up to 39321347] (imputed)   N
# 2  Affymetrix, Illumina [up to 39321347] (imputed)   N
# 3  Affymetrix, Illumina [up to 39321347] (imputed)   N
# 4  Affymetrix, Illumina [up to 39321347] (imputed)   N
#
#                                         MAPPED_TRAIT  \
# 0  diastolic blood pressure, alcohol consumption ...
# 1  diastolic blood pressure, alcohol consumption ...
# 2  diastolic blood pressure, alcohol consumption ...
# 3  diastolic blood pressure, alcohol consumption ...
# 4  diastolic blood pressure, alcohol consumption ...
#
#                                     MAPPED_TRAIT_URI  STUDY ACCESSION  \
# 0  http://www.ebi.ac.uk/efo/EFO_0006336, http://w...       GCST006169
# 1  http://www.ebi.ac.uk/efo/EFO_0006336, http://w...       GCST006169
# 2  http://www.ebi.ac.uk/efo/EFO_0006336, http://w...       GCST006169
# 3  http://www.ebi.ac.uk/efo/EFO_0006336, http://w...       GCST006169
# 4  http://www.ebi.ac.uk/efo/EFO_0006336, http://w...       GCST006169
#
#           GENOTYPING TECHNOLOGY
# 0  Genome-wide genotyping array
# 1  Genome-wide genotyping array
# 2  Genome-wide genotyping array
# 3  Genome-wide genotyping array
# 4  Genome-wide genotyping array
#
# [5 rows x 38 columns]
# /home/johli/anaconda3/envs/aparent/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3049: DtypeWarning: Columns (9,23,27,29,30,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
gwas_df.columns.values
# Out:
# array(['DATE ADDED TO CATALOG', 'PUBMEDID', 'FIRST AUTHOR', 'DATE',
#        'JOURNAL', 'LINK', 'STUDY', 'DISEASE/TRAIT', 'INITIAL SAMPLE SIZE',
#        'REPLICATION SAMPLE SIZE', 'REGION', 'CHR_ID', 'CHR_POS',
#        'REPORTED GENE(S)', 'MAPPED_GENE', 'UPSTREAM_GENE_ID',
#        'DOWNSTREAM_GENE_ID', 'SNP_GENE_IDS', 'UPSTREAM_GENE_DISTANCE',
#        'DOWNSTREAM_GENE_DISTANCE', 'STRONGEST SNP-RISK ALLELE', 'SNPS',
#        'MERGED', 'SNP_ID_CURRENT', 'CONTEXT', 'INTERGENIC',
#        'RISK ALLELE FREQUENCY', 'P-VALUE', 'PVALUE_MLOG',
#        'P-VALUE (TEXT)', 'OR or BETA', '95% CI (TEXT)',
#        'PLATFORM [SNPS PASSING QC]', 'CNV', 'MAPPED_TRAIT',
#        'MAPPED_TRAIT_URI', 'STUDY ACCESSION', 'GENOTYPING TECHNOLOGY'],
#       dtype=object)

# %%
gwas_df['STRONGEST SNP-RISK ALLELE']
# Out:
# 0          rs2013002-T
# 1          rs7953257-A
# 2          rs1579381-C
# 3          rs3753584-T
# 4         rs72640287-T
# 5         rs79211428-T
# 6           rs988397-T
# 7          rs7497026-T
# 8          rs1894400-T
# 9         rs11099097-T
# 10        rs66724425-?
# 11         rs1570204-?
# 12         rs2797560-?
# 13        rs10918274-?
# 14         rs2472496-?
# 15         rs9913911-A
# 16         rs6478746-?
# 17        rs28500712-?
# 18        rs12377624-?
# 19         rs2745572-A
# 20          rs199529-?
# 21         rs1558225-?
# 22        rs34952318-?
# 23         rs6065171-?
# 24         rs6095946-?
# 25         rs4629237-?
# 26        rs76945759-?
# 27         rs9608740-?
# 28          rs756481-?
# 29         rs5756813-?
#               ...
# 161495    rs13059636-?
# 161496     rs3850174-?
# 161497     rs1906508-?
# 161498     rs4241964-?
# 161499     rs4992300-?
# 161500     rs4246036-?
# 161501     rs2842638-?
# 161502     rs2653343-?
# 161503    rs28479767-?
# 161504     rs6967481-?
# 161505     rs2189008-?
# 161506    rs35524253-?
# 161507     rs1470764-?
# 161508    rs10976942-?
# 161509    rs10818834-?
# 161510     rs4752593-?
# 161511     rs6599694-?
# 161512    rs17577073-?
# 161513    rs10891630-?
# 161514     rs7313852-?
# 161515    rs11183201-?
# 161516    rs61963491-?
# 161517     rs4270038-?
# 161518    rs10148448-?
# 161519    rs35746112-?
# 161520     rs2518022-?
# 161521    rs62082401-?
# 161522     rs1013987-?
# 161523    rs78095690-?
# 161524     rs2072727-?
# Name: STRONGEST SNP-RISK ALLELE, Length: 161525, dtype: object

# %%
gwas_bed = gwas_df[['CHR_ID', 'CHR_POS', 'MAPPED_GENE', 'DISEASE/TRAIT', 'STRONGEST SNP-RISK ALLELE', 'P-VALUE', 'PVALUE_MLOG', 'CONTEXT']]
gwas_bed = gwas_bed.rename(columns={
    'CHR_ID' : 'chr',
    'CHR_POS' : 'start',
    'MAPPED_GENE' : 'gene',
    'DISEASE/TRAIT' : 'trait',
    'STRONGEST SNP-RISK ALLELE' : 'snp_id',
    'P-VALUE' : 'p_value',
    'PVALUE_MLOG' : 'p_value_mlog',
    'CONTEXT' : 'molecular_cause'
})

gwas_bed = gwas_bed.loc[~gwas_bed['start'].str.contains(";", na=True)].copy().reset_index(drop=True)
gwas_bed = gwas_bed.loc[~gwas_bed['start'].str.contains("x", na=True)].copy().reset_index(drop=True)
gwas_bed = gwas_bed.loc[gwas_bed['snp_id'].str.len() <= 20].copy().reset_index(drop=True)

gwas_bed = gwas_bed.sort_values(by='p_value_mlog', ascending=False)
gwas_bed = gwas_bed.drop_duplicates(subset='snp_id', keep='first')

gwas_bed['end'] = pd.to_numeric(gwas_bed['start']) + 1
gwas_bed['end'] = gwas_bed['end'].astype(int).astype(str)

gwas_bed = gwas_bed[['chr', 'start', 'end', 'gene', 'trait', 'snp_id', 'p_value', 'p_value_mlog', 'molecular_cause']]

gwas_bed['chr'] = "chr" + gwas_bed['chr']

# %%
gwas_bed
# Out:
#           chr      start        end  \
# 35891   chr19   51125272   51125273
# 35870    chr1  161509955  161509956
# 37261   chr12    9984073    9984074
# 15759    chr7  121322110  121322111
# 37790   chr19   10285007   10285008
# 112100   chr2  210678331  210678332
# 29227    chr6   43957870   43957871
# 38500   chr17   28367840   28367841
# 37904   chr20    1915642    1915643
# 37120   chr12    6455044    6455045
# 38321    chr3   46576229   46576230
# 34776   chr19   54255498   54255499
# 121405   chr2  233762816  233762817
# 37341    chr7  130298758  130298759
# 37618    chr1  154453788  154453789
# 38728    chr2     277003     277004
# 49558   chr11   61803311   61803312
# 139471  chr12  121779004  121779005
# 35682   chr14  105738685  105738686
# 37628   chr19   44913484   44913485
# 37509    chr1   65619842   65619843
# 75534   chr10   98399379   98399380
# 25264   chr19    7668969    7668970
# 37257    chr5   96916728   96916729
# 121002  chr11   64657495   64657496
# 136512   chr3   56815721   56815722
# 35839   chr20    1915180    1915181
# 35710   chr16    1241596    1241597
# 34741   chr19   54251270   54251271
# 35623   chr12  103946426  103946427
# ...       ...        ...        ...
# 122553   chr4  179744323  179744324
# 76327   chr13   71473964   71473965
# 122559   chr8    4156587    4156588
# 122562  chr21   39017535   39017536
# 76332   chr11   18429549   18429550
# 49599    chr4  144957432  144957433
# 49606    chr5   61806954   61806955
# 49612    chr8  138483259  138483260
# 23342    chr7   23931916   23931917
# 51063    chr1  108850215  108850216
# 51055   chr16   81741193   81741194
# 71766   chr17   77404018   77404019
# 51045   chr12  124409638  124409639
# 51044   chr21   18109036   18109037
# 23361   chr11   92422052   92422053
# 23360    chr9  110213589  110213590
# 49863   chr14   88971072   88971073
# 49854    chr5   45285616   45285617
# 49848    chr5   38778412   38778413
# 71750   chr20   60323151   60323152
# 8152     chr6   32632894   32632895
# 76219    chr1  195821528  195821529
# 64328   chr10   18724467   18724468
# 64329   chr10   18889952   18889953
# 49819    chr3  136088767  136088768
# 16143    chr6  115573532  115573533
# 71734    chr2  121054648  121054649
# 71729    chr3  185424069  185424070
# 49615    chr5   26402141   26402142
# 22405    chr9   87889799   87889800
#
#                                                      gene  \
# 35891                                             SIGLEC9
# 35870                                              FCGR2A
# 37261                                             CLEC12A
# 15759                                       CPED1 - WNT16
# 37790                                   ICAM1, AC011511.2
# 112100                                               CPS1
# 29227                             AL157371.1 - AL109615.3
# 38500                  SARM1, AC002094.1, AC002094.3, VTN
# 37904                                               SIRPA
# 37120                                              TAPBPL
# 38321                                        LRRC2, TDGF1
# 34776              LILRB5, LILRB5, LILRB5, LILRB5, LILRB5
# 121405  UGT1A6, UGT1A9, UGT1A1, UGT1A3, UGT1A7, UGT1A4...
# 37341                                                CPA4
# 37618                                                IL6R
# 38728                                                ACP1
# 49558                                        FADS2, FADS1
# 139471                                     TMEM120B, RHOF
# 35682                                        IGHG1, IGHG1
# 37628                                          AC011481.3
# 37509                                                LEPR
# 75534                                             PYROXD2
# 25264                                    RPS27AP19 - RETN
# 37257                                   AC009126.1, ERAP2
# 121002                                  AP001092.1, NRXN2
# 136512                                            ARHGEF3
# 35839                                               SIRPA
# 35710                                              TPSAB1
# 34741              LILRB5, LILRB5, LILRB5, LILRB5, LILRB5
# 35623                                   C12orf73, HSP90B1
# ...                                                   ...
# 122553                            AC020551.1 - AC021193.1
# 76327                                               DACH1
# 122559                                              CSMD1
# 122562                                         AF064858.1
# 76332                                                LDHC
# 49599                                 AC098588.1, ANAPC10
# 49606                                C5orf64 - AC026434.2
# 49612                                             FAM135B
# 23342                              AC003087.1 - RNA5SP228
# 51063                                  AL449266.1, AKNAD1
# 51055                                   AC099524.1, PLCG2
# 71766                                               SEPT9
# 51045                                               NCOR2
# 51044                                   CHODL, AF130417.1
# 23361                                                FAT3
# 23360                                      C9orf152 - TXN
# 49863                                   TTC8 - AL137785.1
# 49854                                                HCN1
# 49848                                            OSMR-AS1
# 71750                                            MIR646HG
# 8152    HLA-DQA1, HLA-DQA1, HLA-DQA1, HLA-DQA1, HLA-DQ...
# 76219                              AL353072.2 - LINC01724
# 64328                                     ARL5B - AIFM1P1
# 64329                             AL512641.1 - AL357520.1
# 49819                                             PPP2R3A
# 16143                              AL606845.1 - LINC02534
# 71734                                RF00019 - AC067960.1
# 71729                                             MAP3K13
# 49615                             AC025475.1 - AC025475.2
# 22405                               SPATA31E1 - SPATA31C1
#
#                                                     trait         snp_id  \
# 35891                                Blood protein levels    rs2075803-G
# 35870                                Blood protein levels    rs1801274-G
# 37261                                Blood protein levels    rs2961544-A
# 15759                           Heel bone mineral density    rs2908007-?
# 37790                                Blood protein levels       rs5498-G
# 112100                                     Glycine levels        rs715-C
# 29227           Vascular endothelial growth factor levels    rs6921438-A
# 38500                                Blood protein levels        rs704-A
# 37904                                Blood protein levels    rs6136377-G
# 37120                                Blood protein levels    rs2532497-A
# 38321                                Blood protein levels    rs6769392-A
# 34776                                Blood protein levels   rs12975366-C
# 121405                             Total bilirubin levels   rs28946889-?
# 37341                                Blood protein levels   rs34587586-T
# 37618                                Blood protein levels    rs4129267-T
# 38728                                Blood protein levels   rs79716074-G
# 49558   Plasma omega-6 polyunsaturated fatty acid leve...     rs174547-C
# 139471                               Mean platelet volume   rs11553699-G
# 35682                                Blood protein levels   rs12147642-T
# 37628                                Blood protein levels     rs438811-T
# 37509                                Blood protein levels    rs3790438-A
# 75534                             Blood metabolite levels    rs4488133-A
# 25264                                     Resistin levels    rs3219175-A
# 37257                                Blood protein levels    rs2927608-A
# 121002                             Serum uric acid levels   rs57633992-?
# 136512                               Mean platelet volume    rs1354034-C
# 35839                                Blood protein levels   rs17855611-A
# 35710                                Blood protein levels  rs144979264-G
# 34741                                Blood protein levels   rs12986064-C
# 35623                                Blood protein levels    rs1165693-A
# ...                                                   ...            ...
# 122553                  Nicotine dependence symptom count   rs17090639-G
# 76327            Amyotrophic lateral sclerosis (sporadic)    rs9599848-?
# 122559                  Nicotine dependence symptom count   rs74442193-G
# 122562                  Nicotine dependence symptom count   rs74819631-G
# 76332            Amyotrophic lateral sclerosis (sporadic)    rs3740713-?
# 49599   Angiotensin-converting enzyme inhibitor intole...    rs1648053-?
# 49606   Angiotensin-converting enzyme inhibitor intole...   rs77652464-?
# 49612   Angiotensin-converting enzyme inhibitor intole...     rs957322-?
# 23342                      Late-onset Alzheimer's disease  rs112920270-A
# 51063   Adverse response to chemotherapy (neutropenia/...    rs1277203-A
# 51055   Adverse response to chemotherapy (neutropenia/...   rs12446319-A
# 71766                                 Airflow obstruction     rs892961-?
# 51045   Adverse response to chemotherapy (neutropenia/...   rs12582168-C
# 51044   Adverse response to chemotherapy (neutropenia/...    rs2055011-C
# 23361                      Late-onset Alzheimer's disease  rs147582129-T
# 23360                      Late-onset Alzheimer's disease  rs116530595-T
# 49863                                Hormone measurements   rs12589060-G
# 49854                                       Breast cancer     rs981782-C
# 49848             Gestational age at birth (child effect)    rs9687972-C
# 71750                            Lentiform nucleus volume    rs6027511-C
# 8152    PEG-asparaginase hypersensitivity without enzy...    rs9272131-T
# 76219                                  Cocaine dependence    rs6677435-?
# 64328                         Immunoglobulin A vasculitis   rs11015915-A
# 64329                         Immunoglobulin A vasculitis   rs72781262-G
# 49819             Gestational age at birth (child effect)    rs9810089-C
# 16143                                           Longevity  rs118113034-?
# 71734                            Capecitabine sensitivity    rs4848143-?
# 71729                                 Airflow obstruction    rs7629245-T
# 49615   Angiotensin-converting enzyme inhibitor intole...    rs7708945-?
# 22405   Serum platinum levels after completion of cisp...   rs73653973-T
#
#         p_value  p_value_mlog                     molecular_cause
# 35891   6E-2142   2141.221849                    missense_variant
# 35870   1E-2102   2102.000000                    missense_variant
# 37261   9E-1973   1972.045757                 3_prime_UTR_variant
# 15759   7E-1700   1699.154902                  intergenic_variant
# 37790   8E-1683   1682.096910                    missense_variant
# 112100  3E-1632   1631.522879                 3_prime_UTR_variant
# 29227   2E-1449   1448.698970                  intergenic_variant
# 38500   1E-1442   1442.000000                    missense_variant
# 37904   8E-1361   1360.096910                      intron_variant
# 37120   4E-1297   1296.397940                      intron_variant
# 38321   5E-1296   1295.301030                      intron_variant
# 34776   3E-1276   1275.522879                    missense_variant
# 121405  3E-1255   1254.522879                      intron_variant
# 37341   4E-1248   1247.397940                    missense_variant
# 37618   7E-1101   1100.154902                      intron_variant
# 38728   1E-1095   1095.000000                    missense_variant
# 49558         0    970.522879                      intron_variant
# 139471        0    925.000000                 3_prime_UTR_variant
# 35682    2E-908    907.698970                      intron_variant
# 37628    9E-875    874.045757  non_coding_transcript_exon_variant
# 37509    3E-861    860.522879                      intron_variant
# 75534         0    859.522879                      intron_variant
# 25264    2E-858    857.698970           regulatory_region_variant
# 37257    7E-858    857.154902                      intron_variant
# 121002   7E-845    844.154902                      intron_variant
# 136512        0    833.000000                      intron_variant
# 35839    2E-822    821.698970                    missense_variant
# 35710    2E-819    818.698970                    missense_variant
# 34741    2E-803    802.698970  non_coding_transcript_exon_variant
# 35623    4E-795    794.397940                      intron_variant
# ...         ...           ...                                 ...
# 122553     9E-6      5.045757                  intergenic_variant
# 76327     9e-06      5.045757                      intron_variant
# 122559     9E-6      5.045757                      intron_variant
# 122562     9E-6      5.045757  non_coding_transcript_exon_variant
# 76332     9e-06      5.045757                      intron_variant
# 49599     9e-06      5.045757                      intron_variant
# 49606     9e-06      5.045757                  intergenic_variant
# 49612     9e-06      5.045757                      intron_variant
# 23342      9E-6      5.045757                  intergenic_variant
# 51063     9e-06      5.045757                      intron_variant
# 51055     9e-06      5.045757                      intron_variant
# 71766     9e-06      5.045757                      intron_variant
# 51045     9e-06      5.045757                      intron_variant
# 51044     9e-06      5.045757                      intron_variant
# 23361      9E-6      5.045757                      intron_variant
# 23360      9E-6      5.045757           regulatory_region_variant
# 49863     9e-06      5.045757                  intergenic_variant
# 49854     9e-06      5.045757                      intron_variant
# 49848     9e-06      5.045757                      intron_variant
# 71750     9e-06      5.045757                      intron_variant
# 8152       9E-6      5.045757                 5_prime_UTR_variant
# 76219     9e-06      5.045757                  intergenic_variant
# 64328     9e-06      5.045757                  intergenic_variant
# 64329     9e-06      5.045757                  intergenic_variant
# 49819     9e-06      5.045757                      intron_variant
# 16143      9E-6      5.045757                  intergenic_variant
# 71734     9e-06      5.045757                  intergenic_variant
# 71729     9e-06      5.045757                      intron_variant
# 49615     9e-06      5.045757                  intergenic_variant
# 22405      9E-6      5.045757                  intergenic_variant
#
# [109459 rows x 9 columns]

# %%
gwas_bed_narrow = gwas_bed[['chr', 'start', 'end', 'snp_id']]

gwas_bed_narrow.to_csv('gwas_bed.bed', sep='\t', header=False, index=False)

print(gwas_bed_narrow.head())
# Out:
#          chr      start        end       snp_id
# 35891  chr19   51125272   51125273  rs2075803-G
# 35870   chr1  161509955  161509956  rs1801274-G
# 37261  chr12    9984073    9984074  rs2961544-A
# 15759   chr7  121322110  121322111  rs2908007-?
# 37790  chr19   10285007   10285008     rs5498-G

# %%
# !./liftOver gwas_bed.bed hg38ToHg19.over.chain gwas_bed_hg19.bed gwas_bed_hg38_unmapped.bed
# Out:
# Reading liftover chains
# Mapping coordinates

# %%
gwas_bed_hg19 = pd.read_csv("gwas_bed_hg19.bed", sep='\t', error_bad_lines=False, names=["chr", "start", "end", "snp_id"])

print(gwas_bed_hg19.head())
# Out:
#      chr      start        end       snp_id
# 0  chr19   51628529   51628530  rs2075803-G
# 1   chr1  161479745  161479746  rs1801274-G
# 2  chr12   10136672   10136673  rs2961544-A
# 3   chr7  120962164  120962165  rs2908007-?
# 4  chr19   10395683   10395684     rs5498-G

# %%
gwas_bed.query("snp_id == 'rs2013002-T'")
# Out:
#         chr      start        end        gene  \
# 4209  chr12  111762346  111762347  AC002996.1
#
#                                                   trait       snp_id p_value  \
# 4209  Diastolic blood pressure x alcohol consumption...  rs2013002-T   4E-39
#
#       p_value_mlog molecular_cause
# 4209      38.39794  intron_variant

# %%
gwas_hg19 = gwas_bed_hg19.join(gwas_bed.set_index("snp_id"), on="snp_id", how="inner", rsuffix="_old")

gwas_hg19 = gwas_hg19[['chr', 'start', 'end', 'gene', 'snp_id', 'trait', 'p_value', 'p_value_mlog', 'molecular_cause']]

print(gwas_hg19.head())
# Out:
#      chr      start        end               gene       snp_id  \
# 0  chr19   51628529   51628530            SIGLEC9  rs2075803-G
# 1   chr1  161479745  161479746             FCGR2A  rs1801274-G
# 2  chr12   10136672   10136673            CLEC12A  rs2961544-A
# 3   chr7  120962164  120962165      CPED1 - WNT16  rs2908007-?
# 4  chr19   10395683   10395684  ICAM1, AC011511.2     rs5498-G
#
#                        trait  p_value  p_value_mlog      molecular_cause
# 0       Blood protein levels  6E-2142   2141.221849     missense_variant
# 1       Blood protein levels  1E-2102   2102.000000     missense_variant
# 2       Blood protein levels  9E-1973   1972.045757  3_prime_UTR_variant
# 3  Heel bone mineral density  7E-1700   1699.154902   intergenic_variant
# 4       Blood protein levels  8E-1683   1682.096910     missense_variant

# %%
gwas_hg19.to_csv('gwas_catalog_hg19.bed', sep='\t', header=False, index=False)
